# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
file = 'Resources/crime_data/NYPD_Arrests_Data__Historic_.csv'
df = pd.read_csv(file, encoding="ISO-8859-1")
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                   PD_DESC  KY_CD  \
# 0   190294601  11/23/2018  109.0  ASSAULT 2,1,UNCLASSIFIED  106.0
# 1   190266280  11/21/2018  665.0                       NaN    NaN
# 2   190159521  11/19/2018  101.0                 ASSAULT 3  344.0
# 3   190080571  11/16/2018  475.0                       NaN    NaN
# 4   190027735  11/15/2018  475.0                       NaN    NaN
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                FELONY ASSAULT  PL 1200512          F           B
# 1                           NaN  PL 4902001          F           Q
# 2  ASSAULT 3 & RELATED OFFENSES  PL 1200000          M           K
# 3                           NaN  PL 1651601          M           Q
# 4                           NaN  PL 1651601          M           M
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# 0               40                0.0     25-44        M           BLACK
# 1              109                0.0     25-44        M  BLACK HISPANIC
# 2               77                0.0     25-44        M           BLACK
# 3              103                1.0     18-24        M           BLACK
# 4               10                1.0     45-64        M  WHITE HISPANIC
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0   1008096.0    233595.0  40.807816 -73.913863
# 1   1032084.0    216954.0  40.762044 -73.827330
# 2   1003508.0    185056.0  40.674600 -73.930575
# 3   1039726.0    195270.0  40.702482 -73.799922
# 4    984669.0    210807.0  40.745301 -73.998489
#
#                                          Lon_Lat
# 0  POINT (-73.91386266099995 40.807816227000046)
# 1  POINT (-73.82732958099997 40.762043893000055)
# 2   POINT (-73.93057482199998 40.67459999000005)
# 3       POINT (-73.799922252 40.702482133000046)
# 4  POINT (-73.99848931699995 40.745301320000074)

# %%
df = df[[ "ARREST_DATE", "PD_DESC", "OFNS_DESC",  "ARREST_BORO", "ARREST_PRECINCT",  "AGE_GROUP", "PERP_SEX", "PERP_RACE"]].dropna()
df
# Out:
#         ARREST_DATE                              PD_DESC  \
# 0        11/23/2018             ASSAULT 2,1,UNCLASSIFIED
# 2        11/19/2018                            ASSAULT 3
# 6        11/12/2018                            ASSAULT 3
# 7        11/08/2018                            ASSAULT 3
# 8        11/06/2018                 TRESPASS 3, CRIMINAL
# ...             ...                                  ...
# 5012951  01/11/2006      TRAFFIC,UNCLASSIFIED INFRACTION
# 5012952  01/05/2006      THEFT OF SERVICES, UNCLASSIFIED
# 5012953  01/05/2006  MANUFACTURE UNAUTHORIZED RECORDINGS
# 5012954  01/10/2006      TRAFFIC,UNCLASSIFIED INFRACTION
# 5012955  01/06/2006         CONTROLLED SUBSTANCE, SALE 5
#
#                                OFNS_DESC ARREST_BORO  ARREST_PRECINCT  \
# 0                         FELONY ASSAULT           B               40
# 2           ASSAULT 3 & RELATED OFFENSES           K               77
# 6           ASSAULT 3 & RELATED OFFENSES           M               33
# 7           ASSAULT 3 & RELATED OFFENSES           K               69
# 8                      CRIMINAL TRESPASS           M                1
# ...                                  ...         ...              ...
# 5012951         OTHER TRAFFIC INFRACTION           Q              104
# 5012952  OTHER OFFENSES RELATED TO THEFT           M               25
# 5012953          MISCELLANEOUS PENAL LAW           K               88
# 5012954         OTHER TRAFFIC INFRACTION           Q              108
# 5012955                  DANGEROUS DRUGS           K               61
#
#         AGE_GROUP PERP_SEX       PERP_RACE
# 0           25-44        M           BLACK
# 2           25-44        M           BLACK
# 6           45-64        F           BLACK
# 7             <18        F           BLACK
# 8           45-64        M           WHITE
# ...           ...      ...             ...
# 5012951     18-24        M  WHITE HISPANIC
# 5012952     45-64        M           BLACK
# 5012953     45-64        M           BLACK
# 5012954     25-44        M           WHITE
# 5012955     25-44        M  WHITE HISPANIC
#
# [5003906 rows x 8 columns]

# %%
nypd_df = df.rename(columns={"ARREST_DATE": "arrest_date",
                        "PD_DESC": "police_description",
                        "OFNS_DESC": "offense_description",
                        "ARREST_BORO": "boro_code",
                        "ARREST_PRECINCT": "arresting_precinct",
                        "AGE_GROUP": "age_range",
                        "PERP_SEX": "sex",
                        "PERP_RACE": "race"
                                                })
nypd_df.head()
# Out:
#   arrest_date        police_description           offense_description  \
# 0  11/23/2018  ASSAULT 2,1,UNCLASSIFIED                FELONY ASSAULT
# 2  11/19/2018                 ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 6  11/12/2018                 ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 7  11/08/2018                 ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 8  11/06/2018      TRESPASS 3, CRIMINAL             CRIMINAL TRESPASS
#
#   boro_code  arresting_precinct age_range sex   race
# 0         B                  40     25-44   M  BLACK
# 2         K                  77     25-44   M  BLACK
# 6         M                  33     45-64   F  BLACK
# 7         K                  69       <18   F  BLACK
# 8         M                   1     45-64   M  WHITE

# %%
rds_connection_string = "postgres:boozer11@localhost:5432/police-violence-racial-equity"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['dallas', 'nypd']

# %%
nypd_df.to_sql(name = "nypd", con = engine, if_exists = "append", index = False)

# %%
pd.read_sql_query('select *  from nypd;',con=engine)
# Out:
#         arrest_date                          police_description  \
# 0        05/28/2017  MISCHIEF,CRIMINAL,    UNCL 2ND DEG 3RD DEG
# 1        06/04/2017                                   ASSAULT 3
# 2        06/09/2017      NY STATE LAWS,UNCLASSIFIED MISDEMEANOR
# 3        05/27/2017  LARCENY,GRAND FROM OPEN AREAS,UNCLASSIFIED
# 4        06/05/2017             THEFT OF SERVICES, UNCLASSIFIED
# ...             ...                                         ...
# 5003901  06/05/2017  LARCENY,PETIT FROM OPEN AREAS,UNCLASSIFIED
# 5003902  06/18/2017                         OBSTR BREATH/CIRCUL
# 5003903  05/31/2017                                     TAX LAW
# 5003904  06/08/2017                        TRESPASS 2, CRIMINAL
# 5003905  06/13/2017             THEFT OF SERVICES, UNCLASSIFIED
#
#                           offense_description boro_code arresting_precinct  \
# 0        CRIMINAL MISCHIEF & RELATED OFFENSES         Q                101
# 1                ASSAULT 3 & RELATED OFFENSES         Q                105
# 2            OTHER STATE LAWS (NON PENAL LAW)         K                 78
# 3                               GRAND LARCENY         B                 40
# 4             OTHER OFFENSES RELATED TO THEFT         B                 47
# ...                                       ...       ...                ...
# 5003901                         PETIT LARCENY         K                 77
# 5003902          ASSAULT 3 & RELATED OFFENSES         Q                101
# 5003903        OTHER STATE LAWS (NON PENAL LA         M                 25
# 5003904                     CRIMINAL TRESPASS         Q                109
# 5003905       OTHER OFFENSES RELATED TO THEFT         B                 44
#
#         age_range sex            race
# 0           45-64   F  WHITE HISPANIC
# 1           25-44   M           BLACK
# 2           25-44   M           BLACK
# 3             <18   F  WHITE HISPANIC
# 4           25-44   M           BLACK
# ...           ...  ..             ...
# 5003901     18-24   M           BLACK
# 5003902     25-44   M  WHITE HISPANIC
# 5003903     25-44   M           WHITE
# 5003904     25-44   M           BLACK
# 5003905     18-24   M  WHITE HISPANIC
#
# [5003906 rows x 8 columns]
